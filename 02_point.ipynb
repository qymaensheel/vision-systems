# %% [markdown]
# # Przekształcenia punktowe

# %% [markdown]
# W trakcie niniejszego ćwiczenia zapoznamy się z podstawowymi operacjami punktowymi (bezkontekstowymi) przeprowadzanymi na obrazach cyfrowych:
# - typu LUT (operacja jednoargumentowa),
# - arytmetycznymi (operacje dwuargumentowe): dodawanie, odejmowanie, mnożenie, dzielenie,
# - logicznymi (operacje jedno i dwuargumentowe): AND, OR, XOR, NOT.

# %% [markdown]
# Na początku zaimportuj potrzebne biblioteki.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import numpy as np

# %% [markdown]
# ## Operacja LUT
#
# **Operacja LUT** polega na przekształcaniu wartości poszczególnych pikseli obrazu przy użyciu z góry przygotowanych tabel przekodowań (tabel korekcji).
#
# W przetwarzaniu obrazów najczęściej wykorzystuje się następujące funkcje:
# - typu kwadratowa, pierwiastek kwadratowy
# - typu logarytm, odwrócony logarytm
# - typu wykładnicza,
# - inne (np. piłokształtna).

# %% [markdown]
# W tym zadaniu zostały dla Państwa przygotowane tablice przekodowania.
# Proszę pobrać je z githuba `https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/lut.py` (można użyć znanego polecenia !wget), a następnie zaimportować je poleceniem `import lut`.
# Od tego momentu można się do nich odwoływać w następujący sposób: `lut.log` itd.

# %%
if not os.path.exists("lut.py") :
    # !wget https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/lut.py
import lut

# %% [markdown]
# Wyświetl przykładowe przekodowanie wykorzystując funkcję `plt.plot(lut.kwadratowa)`.

# %%
plt.plot(lut.kwadratowa)

# %% [markdown]
# Wybierz jeden z obrazów: _lena.bmp_ lub _jet.bmp_ (w razie potrzeby pobierz go z githuba):
# - https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/lena.bmp
# - https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/jet.bmp
#
# Wczytaj go i wyświetl.

# %%
if not os.path.exists("jet.bmp") :
    # !wget https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/jet.bmp
        
I = cv2.imread('jet.bmp')

plt.imshow(I)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Na wybranym obrazie wykonaj operację LUT.
# Służy do tego funkcja `cv2.LUT` przyjmująca dwa argumenty: obraz oraz tablicę przekodowania.
# Wybierz dowolną z zaimportowanych tablic i wyświetl wynikowy obraz.

# %%
I2 = []

I2 = cv2.LUT(I, lut.odwrotna)

plt.imshow(I2)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Aby lepiej zobaczyć w jaki sposób działają różne przekodowania LUT, skonstruujemy funkcję, która jako argumenty pobierać będzie obrazek oryginalny oraz tablicę przekodowania, a następnie na wspólnym rysunku będzie wyświetlać: funkcję, obraz wejściowy oraz wynik przekodowania.
#
# Przypomnienie składni tworzenia funkcji w pythonie:
# ```{python}
#   def nazwa_funkcji(para, metry):
#   	# cialo funkcji
# ```

# %% [markdown]
#   - Stwórz nową funkcję i nazwij ją LUT.
#   - Funkcja powinna przyjmować dwa parametry: obraz oraz tablicę przekodowania.
#   - W ciele funkcji wykonaj przekodowanie LUT, podobnie jak wcześniej w przykładzie.
#   - Funkcja powinna wyświetlić wykres składający się z 3 umieszczonych obok siebie pól: wykres przekodowania, obraz oryginalny oraz obraz przekształcony.
#     Każdy z wykresów powinien być podpisany.
#     _(W razie problemów można przypomnieć sobie te zagadnienia z laboratorium wprowadzającego)_
#   - Jeśli wykres przekodowania jest zbyt rozciągnięty, można go wyrównać, np. `ax2.set_aspect('equal')`.

# %%
def LUT(img, tbl, name = ""):
    img2 = cv2.LUT(img, tbl)
    fig, (ax1, ax2, ax3) = plt.subplots(1,3)
    ax1.plot(tbl)
    ax1.set_title("lookup table")
    ax2.imshow(img)
    ax2.set_title("source image")
    ax3.imshow(img2)
    ax3.set_title("converted image")
    fig.suptitle(name)

# %% [markdown]
# Wywołaj przygotowaną funkcję dla każdego z przekształceń.
# W wyniku powinno powstać 7 wykresów.

# %%
LUT(I, lut.log,"logarytmiczna")
LUT(I, lut.pila,"piła")
LUT(I, lut.odwlog,"odwrotna logarytmiczna")
LUT(I, lut.wykladnicza,"wykładnicza")
LUT(I, lut.kwadratowa,"kwadratowa")
LUT(I, lut.odwrotna,"odwrotna")
LUT(I, lut.pierwiastkowa,"pierwiastkowa")

# %% [markdown]
# ## Operacja arytmetyczne
#
# ### Dodawanie
#
# Wczytaj dwa obrazy _lena.bmp_ i _jet.bmp_ i wyświetl je.

# %%
if not os.path.exists("jet.bmp") :
    # !wget https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/jet.bmp
        
jet = cv2.imread('jet.bmp')

plt.imshow(jet)
plt.xticks([]), plt.yticks([])
plt.show()

if not os.path.exists("lena.bmp") :
    # !wget https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/lena.bmp
        
lena = cv2.imread('lena.bmp')

plt.imshow(lena)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Dodaj obrazy _lena_ i _jet_, wykorzystaj funkcję `cv2.add`.
# Uzyskany wynik wyświetl.

# %%
added = cv2.add(lena, jet)

plt.imshow(added)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Czy wynik sumowania jest satysfakcjonujący?
# Co może niekorzystnie wpływać na rezultat operacji?
# Spróbuj wykonać dodawanie ponownie wykorzystując typ uint16 (`jet.astype('uint16')`).
# Wynikowy obraz należy przeskalować do zakresu 0-255, zamienić na typ uint8 i wyświetlić. _
# Uwaga: operacja ta jest użyteczna w przypadku, gdy dane do wyświetlenia wykraczają poza zakres 0-255, w przeciwnym przypadku jej wykorzystanie może zniekształcić wyniki._

# %%
jet2 = jet.astype('uint16')
lena2 = lena.astype('uint16')

res = cv2.add(lena2, jet2)

res = cv2.normalize(res, None, 0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_8U)

plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Kombinacja liniowa
#
# Do wykonywania operacji kombinacji liniowej służy funkcja `cv2.addWeighted`.
# Zapoznaj się z dokumentacją tej funkcji i przetestuj kilka kombinacji liniowych obrazów _lena_ i _jet_.
# Wyświetl wynik dowolnej z nich.

# %%
res = cv2.addWeighted(lena,0.2,jet,0.8,0)
plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Odejmowanie
#
# Wykorzystując funkcję `cv2.subtract` odejmij obrazy _lena_ i _jet_.

# %%
res = cv2.subtract(lena,jet)
plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Czy wynik odejmowania jest satysfakcjonujący?
# Co może niekorzystnie wpływać na rezultat operacji?
# Często zamiast zwykłego odejmowania wykorzystuje się operację wartość bezwzględna z różnicy (pozwala to między innymi uniknąć pokazanych powyżej problemów).
# Zamień typ obrazów _lena_ i _jet_ z uint8 na **int16**, odejmij je od siebie, a następnie wykorzystując funkcję `np.abs` wykonaj operację wartość bezwzględna z różnicy.
# Wyświetl ten obraz.
# Zastanów się, dlaczego ta zmiana poprawia wynik odejmowania?

# %%
jet3 = jet.astype('int16')
lena3 = lena.astype('int16')
res = res.astype('int16')
res = cv2.subtract(lena3,jet3)
res = np.abs(res)



plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Mnożenie
#
# Mnożenie dwóch obrazów pozwala wykonać funkcja `cv2.multiply`.
# Wykonaj mnożenie obrazów _lena_ i _jet_.
# Czy wynik takiej operacji zawiera jakąś istotną informację?
# Dlaczego?

# %%
res = cv2.multiply(lena,jet)

plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

print("Wszystkie piksele wychodzą poza skalę powodując wybielenie")
# Out:
# Wszystkie piksele wychodzą poza skalę powodując wybielenie

# %% [markdown]
# Mnożenie częściej wykorzystuje się jako:
#   + mnożenie przez stałą $-$ co powoduje ogólne rozjaśnienie albo ściemnienie obrazu,
#   + mnożenie przez maskę $-$ czyli obraz binarny.

# %% [markdown]
# Wczytaj maskę _kolo.bmp_ (https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/kolo.bmp).
# Przemnóż wybrany obraz przez maskę i wyświetl wynik.
# Mnożenie przez maskę można zrealizować za pomocą funkcji `cv2.multiply`, ale maskę należy należy najpierw przekształcić z zakresu 0-255 do 0-1, na przykład `(maska).astype('bool').astype('uint8')`.

# %%
if not os.path.exists("kolo.bmp") :
    # !wget https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/kolo.bmp
        
mask = cv2.imread('kolo.bmp')

mask = mask.astype('bool').astype('uint8')

res = cv2.multiply(jet,mask)
plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Negatyw
#
# Negatyw obrazu uzyskuje się za pomocą funkcji `cv2.bitwise_not(img)`
# Negatyw obrazu można również uzyskać wykorzystując przekodowanie LUT.
# Można w tym celu posłużyć się przygotowaną wcześniej tablicą `lut.odwrotna`.
# Przetestuj działanie tych funkcji i wykonaj negatyw obrazu _lena_ dowolnym sposobem.

# %%
res = cv2.bitwise_not(lena)

plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

res = cv2.LUT(lena, lut.odwrotna)

plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Operacje logiczne
#
# Na poszczególnych punktach obrazu (najczęściej binarnego $-$ czyli składającego się z dwóch kolorów: czarnego i białego) można wykonywać operacje logiczne: NOT, AND, OR, XOR itp.
# Wczytaj dwa obrazy: _kolo.bmp_ i _kwadrat.bmp_ (https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/kwadrat.bmp), następnie wyświetl je.

# %%
if not os.path.exists("kwadrat.bmp") :
    # !wget https://raw.githubusercontent.com/vision-agh/poc_sw/master/02_Point/kwadrat.bmp
        
maskSq = cv2.imread('kwadrat.bmp')

plt.imshow(maskSq)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Na wczytanych obrazach wykonaj wybrane operacje logiczne: NOT (operator `~`), AND (`&`), OR (`|`), XOR (`^`).
# Operator `~` jest jednoargumentowy, wszystkie pozostałe są dwuargumentowe.
# Alternatywnym sposobem jest wykorzystanie funkcji z biblioteki opencv: `cv2.bitwise_not`, `cv2.bitwise_and`, `cv2.bitwise_or`, `cv2.bitwise_xor`.
# Wyświetl rezultaty.

# %%
m = ~maskSq
m = m.astype('bool').astype('uint8')
res = cv2.multiply(jet,m)
plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

# %%
m2 = maskSq & mask
m2 = m2.astype('bool').astype('uint8')
res = cv2.multiply(jet,m2)
plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

# %%
m3 = maskSq | mask
m3 = m3.astype('bool').astype('uint8')
res = cv2.multiply(jet,m3)
plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()

# %%
m4 = cv2.bitwise_xor(maskSq.astype('bool').astype('uint8'), mask.astype('bool').astype('uint8'))
m4 = m4.astype('bool').astype('uint8')
res = cv2.multiply(jet,m4)
plt.imshow(res)
plt.xticks([]), plt.yticks([])
plt.show()
